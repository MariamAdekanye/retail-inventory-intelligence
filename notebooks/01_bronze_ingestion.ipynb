# %% [markdown]
# # ******Project Portfolio**

# %% [markdown]
# # *****PARAMETERS**

# %%
dataset = "train"
# Out:
# StatementMeta(, fea7afdb-0220-47bf-98f4-91cc13bf3994, 3, Finished, Available, Finished, False)

# %%
df_train = spark.read.csv("Files/Destination/train.csv", header=True, inferSchema=True)
# df now is a Spark DataFrame containing CSV data from "Files/Destination/train.csv".
display(df_train)
# Out:
# StatementMeta(, f4aa046e-9e29-401c-b4cd-342cd5bfd8ed, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e9edb1da-ebae-41ce-ac59-c8e82501786d)

# %%
df_train.write.format("delta").mode("overwrite").save("Tables/bronze_sales")
# Out:
# StatementMeta(, f4aa046e-9e29-401c-b4cd-342cd5bfd8ed, 6, Finished, Available, Finished, False)

# %%
df_train.write.format("delta").mode("overwrite").save("Tables/bronze/bronze_sales")
# Out:
# StatementMeta(, f4aa046e-9e29-401c-b4cd-342cd5bfd8ed, 7, Finished, Available, Finished, False)

# %%
df_oil = spark.read.csv("Files/Destination/oil.csv", header=True, inferSchema=True)
# df now is a Spark DataFrame containing CSV data from "Files/Destination/oil.csv".
display(df)
# Out:
# StatementMeta(, 67c3677e-a9af-4141-aa44-7150704dd4fd, 14, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0e6f832f-0ea2-46bf-a48b-b43c94a51991)

# %%
df_oil.write.format("delta").mode("overwrite").save("Tables/bronze_oil")
# Out:
# StatementMeta(, 67c3677e-a9af-4141-aa44-7150704dd4fd, 15, Finished, Available, Finished, False)

# %%
df_store = spark.read.csv("Files/Destination/stores.csv", header=True, inferSchema=True)
# df now is a Spark DataFrame containing CSV data from "Files/Destination/stores.csv".
display(df)
# Out:
# StatementMeta(, 67c3677e-a9af-4141-aa44-7150704dd4fd, 16, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f362028e-2232-45c4-b042-3a0399986039)

# %%
df_store.write.format("delta").mode("overwrite").save("Tables/bronze_store")
# Out:
# StatementMeta(, 67c3677e-a9af-4141-aa44-7150704dd4fd, 18, Finished, Available, Finished, False)

# %%
df_holidayevent = spark.read.csv("Files/Destination/holidays_events.csv", header=True, inferSchema=True)
# df now is a Spark DataFrame containing CSV data from "Files/Destination/holidays_events.csv".
display(df)
# Out:
# StatementMeta(, 67c3677e-a9af-4141-aa44-7150704dd4fd, 21, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 320d4dc6-5f1f-436c-88ca-d95312dbcf12)

# %%
df_holidayevent.write.format("delta").mode("overwrite").save("Tables/bronze_holidaysevents")
# Out:
# StatementMeta(, 67c3677e-a9af-4141-aa44-7150704dd4fd, 22, Finished, Available, Finished, False)

# %%
df_train.printSchema()
df_train.show(5)
# Out:
# StatementMeta(, 67c3677e-a9af-4141-aa44-7150704dd4fd, 23, Finished, Available, Finished, False)
# root
#  |-- id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- store_nbr: integer (nullable = true)
#  |-- family: string (nullable = true)
#  |-- sales: double (nullable = true)
#  |-- onpromotion: integer (nullable = true)
#
# +---+----------+---------+----------+-----+-----------+
# | id|      date|store_nbr|    family|sales|onpromotion|
# +---+----------+---------+----------+-----+-----------+
# |  0|2013-01-01|        1|AUTOMOTIVE|  0.0|          0|
# |  1|2013-01-01|        1| BABY CARE|  0.0|          0|
# |  2|2013-01-01|        1|    BEAUTY|  0.0|          0|
# |  3|2013-01-01|        1| BEVERAGES|  0.0|          0|
# |  4|2013-01-01|        1|     BOOKS|  0.0|          0|
# +---+----------+---------+----------+-----+-----------+
# only showing top 5 rows
